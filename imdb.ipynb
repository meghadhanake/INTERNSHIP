# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup 
import requests

# %%
page = requests.get('https://www.bing.com/search?q=imdb%27s+top+rated+100+movies&cvid=1f26c70334ba4cb58f805f66afc61e83&aqs=edge.1.69i57j0l3.3416j0j1&pglt=2083&FORM=ANNTA1&PC=ACTS')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:web="http://schemas.live.com/Web/"><head><script type="text/javascript">//<![CDATA[
# si_ST=new Date
# ...

# %%
article = soup.find('div',class_="carousel-title"")
article
# Out:
#   Input In [13]
#     article = soup.find('div',class_="carousel-title"")
#                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
 images=[]
for i in soup.find_all("div",class_="cardImage")
images.append(i.get('data_src'))

images
# Out:
#   Input In [16]
#     for i in soup.find_all("div",class_="cardImage")
#                                                     ^
# SyntaxError: invalid syntax

# %%
titles = soup.find('div',class_="b_title")
titles
# Out:
# <div class="b_title"><h2><a h="ID=SERP,5188.1" href="https://www.imdb.com/search/title/?groups=top_100&amp;sort=user_rating,desc">IMDb "Top 100" (Sorted by IMDb Rating Descending)</a></h2><div class="b_suffix b_secondaryText nowrap scs_exp siz23 b_floatrt"><a aria-label="Additional Results" class="scs_icn b_hide sc_al" h="ID=SERP,5720.1" href="javascript:void(0)" tabindex="-1"><span aria-expanded="true" aria-label="Show less" class="scs_cls b_hide" role="button" tabindex="0" title="Close"></span><span aria-expanded="false" aria-label="Show more" class="scs_arw" role="button" tabindex="0" title="Explore this page"></span></a><div class="scs_c b_hide cnt_vis_hid scs_load" data-priority="2" data-sc-iid="SERP.5721" data-sc-metadata='{"scenarios":"7,6,14","url":"https://www.imdb.com/search/title/?groups=top_100&amp;sort=user_rating,desc","agi5qv":"agi5qv8545432612251796073"}'></div></div></div>

# %%
one = soup.find('div',class_="lister-item-content")
one

# %%
two= soup.find('div',class_="lister-item mode-advanced")
two
